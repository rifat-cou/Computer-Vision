# %%
# # prompt: read a image using cv2 and show it

# !apt-get -qq install -y libopencv-dev python-opencv
# import cv2
# from google.colab import files

# uploaded = files.upload()

# for fn in uploaded.keys():
#   print('User uploaded file "{name}" with length {length} bytes'.format(
#       name=fn, length=len(uploaded[fn])))

# %%
# For Google Colab: Image display via matplotlib instead of cv2.imshow
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow  # Optional if using cv2_imshow

# %%
# Out:
#      <input type="file" id="files-69e3a2ff-5720-412d-8d4e-668c51587258" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-69e3a2ff-5720-412d-8d4e-668c51587258">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# prompt: load a image already uploaded data named portrait.png

import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow  # Optional if using cv2_imshow
from google.colab import files
import cv2

# Assuming 'portrait.png' was uploaded in the previous cell
# Read the image using cv2
image = cv2.imread('portrait.png')

# Check if the image was loaded successfully
if image is not None:
  # Convert the image from BGR (OpenCV default) to RGB (Matplotlib default)
  img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

  # Display the image using Matplotlib
  plt.imshow(img)

  plt.show()
else:
  print("Error: Could not load image 'portrait.png'. Please ensure the file was uploaded correctly.")

# %%
# Step 1: Upload the image using Colab's file upload
from google.colab import files
import cv2
import matplotlib.pyplot as plt
uploaded = files.upload()

# Step 2: Load the image (get the first uploaded file)
import io
import numpy as np
file_name = next(iter(uploaded))
img = cv2.imdecode(np.frombuffer(uploaded[file_name], np.uint8), cv2.IMREAD_COLOR)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# Out:
#      <input type="file" id="files-1cf5b8e4-490f-4fc1-bb3e-8f12d093c54e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1cf5b8e4-490f-4fc1-bb3e-8f12d093c54e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
plt.imshow(img)

# %%
print(img)
# Out:
# [[[172 183 181]
#   [169 180 178]
#   [170 181 179]
#   ...
#   [101 104 102]
#   [100 101  99]
#   [ 98  99  97]]
#
#  [[171 182 180]
#   [170 181 179]
#   [171 182 180]
#   ...
#   [103 106 104]
#   [103 104 102]
#   [101 102 100]]
#
#  [[170 181 179]
#   [171 182 180]
#   [172 183 181]
#   ...
#   [106 109 107]
#   [106 107 105]
#   [104 105 103]]
#
#  ...
#
#  [[253 252 242]
#   [246 245 235]
#   [243 242 232]
#   ...
#   [134 137 128]
#   [133 135 129]
#   [132 134 128]]
#
#  [[246 243 235]
#   [249 246 238]
#   [242 239 231]
#   ...
#   [135 136 127]
#   [134 135 126]
#   [134 135 126]]
#
#  [[246 243 235]
#   [249 246 238]
#   [242 239 231]
#   ...
#   [135 136 127]
#   [134 135 126]
#   [134 135 126]]]

# %%
print(img.shape)
print(img.dtype)
print(img[50, 50])
print("total number of pixel:", img.size)
imgresize=cv2.resize(img,(200,200))
plt.imshow(imgresize)
# Out:
# (882, 662, 3)
# uint8
# [180 191 181]
# total number of pixel: 1751652

# %%
# Step 3: Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
# Step 3: Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Step 4: Display images using matplotlib
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(gray, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')
plt.show()

# %%
# Step 5: Save the grayscale image (if needed)
cv2.imwrite('output_gray.jpg', gray)
# Out:
# True

# %%
# Step 6: Print image properties
print("Image Shape:", img.shape)
print("Image Data Type:", img.dtype)
print("Pixel Value at (50, 50):", img[50, 50])
# Out:
# Image Shape: (256, 256, 3)
# Image Data Type: uint8
# Pixel Value at (50, 50): [52 44 38]
